# %%
## NEXT STEPS:
##      TAKE OUT SPECIAL CHARACTERS --> DONE
##      CONVERT TEXT INTO LOWERCASE --> DONE
##      REMOVE STOPWORDS AND PUNCTUATION --> DONE
##      ADD LABEL --> LATER
##      READ ALL FILES FROM FOLDER AND COMBINE THEM INTO A SINGLE CSV --> DONE
##      READ FILES FROM S3
##      CONVERT TO GLUE CODE --> NOT NEEDED
##      TRANSLATE REVIEWS TO ENGLISH --> DONE

### EXTRA (FOR LATER)
##      TOKENIZATION
##      STEMMING/LEMMATIZATION

# %%
import os
import re
import shutil
from datetime import datetime
from pyspark.sql import SparkSession
from pyspark.sql.functions import col, explode, regexp_replace, lit, size, udf, lower
from pyspark.sql.types import StructType, StructField, StringType, IntegerType, ArrayType, MapType
from langdetect import detect, LangDetectException
from googletrans import Translator

# Initialize Spark session
spark = SparkSession.builder \
    .appName("HotelDataProcessing") \
    .getOrCreate()

# Path to the local JSON files folder
json_folder_path = '../input/'  # Update this path
output_path = '../output/'  # Update this path as needed

# Get the current date and hour
current_datetime = datetime.now().strftime("%Y-%m-%d_%H-%M-%S")

# Define the schema
schema = StructType([
    StructField("hotel_name", StringType(), True),
    StructField("location", StringType(), True),
    StructField("rating", StringType(), True),
    StructField("user_ratings_total", IntegerType(), True),
    StructField("max_number_of_people", IntegerType(), True),
    StructField("address", StringType(), True),
    StructField("business_status", StringType(), True),
    StructField("place_id", StringType(), True),
    StructField("amenities", MapType(StringType(), StringType()), True),
    StructField("photos", ArrayType(
        StructType([
            StructField("photo_reference", StringType(), True),
            StructField("s3_url", StringType(), True),
            StructField("html_attributions", ArrayType(StringType()), True)
        ])
    ), True),
    StructField("reviews", ArrayType(
        StructType([
            StructField("user", StringType(), True),
            StructField("rating", StringType(), True),
            StructField("date", StringType(), True),
            StructField("review", StringType(), True)
        ])
    ), True),
    StructField("source", StringType(), True)
])

# Define a UDF to convert relative dates to number of days
def convert_to_days(date_str):
    try:
        if "day" in date_str:
            days = int(re.findall(r'\d+', date_str)[0])
        elif "week" in date_str:
            days = int(re.findall(r'\d+', date_str)[0]) * 7
        elif "month" in date_str:
            days = int(re.findall(r'\d+', date_str)[0]) * 30
        elif "year" in date_str:
            days = int(re.findall(r'\d+', date_str)[0]) * 365
        else:
            days = 0
    except (ValueError, IndexError):
        days = 0
    return days

convert_to_days_udf = udf(convert_to_days, IntegerType())

# Define a UDF to detect the language of the review
def detect_language(text):
    try:
        return detect(text)
    except LangDetectException:
        return 'unknown'

detect_language_udf = udf(detect_language, StringType())

# Initialize an empty DataFrame with the target schema
empty_df_schema = StructType([
    StructField("region", StringType(), True),
    StructField("hotel_name", StringType(), True),
    StructField("rating", StringType(), True),
    StructField("user_ratings_total", IntegerType(), True),
    StructField("number_of_photos", IntegerType(), True),
    StructField("address", StringType(), True),
    StructField("business_status", StringType(), True),
    StructField("review_user", StringType(), True),
    StructField("review_rating", StringType(), True),
    StructField("review_date_in_days", IntegerType(), True),
    StructField("review_text", StringType(), True),
    StructField("review_language", StringType(), True),
    StructField("review_text_translated", StringType(), True)
])

combined_df = spark.createDataFrame([], empty_df_schema)

# Iterate over all JSON files in the folder
for file_name in os.listdir(json_folder_path):
    if file_name.endswith('.json'):
        # Extract region from the file name
        region = file_name.split('_')[0]
        json_file_path = os.path.join(json_folder_path, file_name)
        
        # Load JSON data from the local file with schema and multiline option
        df = spark.read.schema(schema).option("multiline", "true").json(json_file_path)
        
        # Explode the reviews array to analyze individual reviews
        exploded_df = df.select(
            col("hotel_name"),
            col("rating"),
            col("user_ratings_total"),
            col("address"),
            col("business_status"),
            size(col("photos")).alias("number_of_photos"),  # Add column for number of photos
            explode(col("reviews")).alias("review")
        )
        
        # Flatten the DataFrame, replace newline and carriage return characters with spaces, remove special characters, and convert to lowercase
        flattened_df = exploded_df.select(
            lit(region).alias("region"),  # Add region as a new column
            col("hotel_name"),
            col("rating"),
            col("user_ratings_total"),
            col("number_of_photos"),  # Include the number of photos column
            col("address"),
            col("business_status"),
            col("review.user").alias("review_user"),
            col("review.rating").alias("review_rating"),
            convert_to_days_udf(col("review.date")).alias("review_date_in_days"),  # Convert review date to days
            lower(regexp_replace(regexp_replace(regexp_replace(col("review.review"), "\n", ""), "\r", ""), "[^a-zA-Z0-9\s]", "")).alias("review_text"),
            detect_language_udf(col("review.review")).alias("review_language")  # Detect language
        )
        
        # Convert to Pandas DataFrame for translation
        flattened_pdf = flattened_df.toPandas()
        
        # Initialize the translator
        translator = Translator()

        # Translate non-English reviews to English
        for index, row in flattened_pdf.iterrows():
            if row['review_language'] != 'en' and row['review_language'] != 'unknown':
                try:
                    translated_text = translator.translate(row['review_text'], dest='en').text
                    flattened_pdf.at[index, 'review_text_translated'] = translated_text
                except Exception as e:
                    flattened_pdf.at[index, 'review_text_translated'] = row['review_text']  # If translation fails, use original text
            else:
                flattened_pdf.at[index, 'review_text_translated'] = row['review_text']

        # Convert back to Spark DataFrame
        translated_df = spark.createDataFrame(flattened_pdf, schema=empty_df_schema)
        
        # Append to the combined DataFrame
        combined_df = combined_df.unionByName(translated_df)

# Coalesce the combined DataFrame to a single partition
combined_df = combined_df.coalesce(1)

# Show the combined DataFrame
print("Combined DataFrame:")
combined_df.show(truncate=False)

# Save the combined DataFrame to a temporary CSV file
temp_output_path = os.path.join(output_path, "temp_output")
combined_df.write.mode("overwrite").csv(temp_output_path, header=True)

# Rename the output file
output_file_name = f"l1_data_{current_datetime}.csv"
temp_file_path = os.path.join(temp_output_path, "part-*.csv")
final_output_path = os.path.join(output_path, output_file_name)

# Move the file to the final output path
for file in os.listdir(temp_output_path):
    if file.startswith("part-") and file.endswith(".csv"):
        shutil.move(os.path.join(temp_output_path, file), final_output_path)

# Remove the temporary directory
shutil.rmtree(temp_output_path)

# Stop the Spark session
spark.stop()
# Out:
# Combined DataFrame:
# +----------------+----------------------------+------+------------------+----------------+--------------------------------------------------------------+---------------+-----------------------------+-------------+-------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+---------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |region          |hotel_name                  |rating|user_ratings_total|number_of_photos|address                                                       |business_status|review_user                  |review_rating|review_date_in_days|review_text                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   |review_language|review_text_translated                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        |
# +----------------+----------------------------+------+------------------+----------------+--------------------------------------------------------------+---------------+-----------------------------+-------------+-------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+---------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |dummy           |Grand Plaza Hotel & Wellness|4.5   |1301              |10              |Carrer de na Maria Pla, 19-21, AD500 Andorra la Vella, Andorra|OPERATIONAL    |Scarlet Cortés Santelices    |5            |60                 |im back in andorra and once again the hotel was amazing felipe and jose looked after us and they were super nice and attentive the whole time the spa needs an appointment but its seriously awesome and totally worth it plus the hotel is really close to all the shops which is awesome                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    |en             |im back in andorra and once again the hotel was amazing felipe and jose looked after us and they were super nice and attentive the whole time the spa needs an appointment but its seriously awesome and totally worth it plus the hotel is really close to all the shops which is awesome                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    |
# |dummy           |Grand Plaza Hotel & Wellness|4.5   |1301              |10              |Carrer de na Maria Pla, 19-21, AD500 Andorra la Vella, Andorra|OPERATIONAL    |Tatiana Siivinen             |4            |90                 |nice hotel in good location we stayed 5 days there they have 2 restaurants italian  very nice  and spanish  noodle was very salty and spicy and we asked if they are spicy before we order but burger and meat was ok  room was nice in the way but very very hot one night it was 275  all others 255 c we asked in the hotel and they told us that it is a temperature in the hotel so we cant change it we been opening window every once in the while but our girl was sleeping next to window so we couldnt keep it open for night nice breakfast with a lot of fruits spa is little but nice gym is little but ok  also very hot in there cause it is right next to spa department because of the uncomfortable nights in the hotel i wouldnt give it 5 stars                                                                                                                                                                                                                                                                                                                                                                                                           |en             |nice hotel in good location we stayed 5 days there they have 2 restaurants italian  very nice  and spanish  noodle was very salty and spicy and we asked if they are spicy before we order but burger and meat was ok  room was nice in the way but very very hot one night it was 275  all others 255 c we asked in the hotel and they told us that it is a temperature in the hotel so we cant change it we been opening window every once in the while but our girl was sleeping next to window so we couldnt keep it open for night nice breakfast with a lot of fruits spa is little but nice gym is little but ok  also very hot in there cause it is right next to spa department because of the uncomfortable nights in the hotel i wouldnt give it 5 stars                                                                                                                                                                                                                                                                                                                                                                                                           |
# |dummy           |Grand Plaza Hotel & Wellness|4.5   |1301              |10              |Carrer de na Maria Pla, 19-21, AD500 Andorra la Vella, Andorra|OPERATIONAL    |Liudmyla Ресурсное настроение|5            |120                |very nice hotel we stayed  there during our ski trip in january pleasant friendly receptionist delicious breakfast when we arrived the pianist was playing  in the lobby and made the atmosphere magical  recommend to book spa in advance coz when we arrive the spa was already fully booked                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                |en             |very nice hotel we stayed  there during our ski trip in january pleasant friendly receptionist delicious breakfast when we arrived the pianist was playing  in the lobby and made the atmosphere magical  recommend to book spa in advance coz when we arrive the spa was already fully booked                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                |
# |dummy           |Grand Plaza Hotel & Wellness|4.5   |1301              |10              |Carrer de na Maria Pla, 19-21, AD500 Andorra la Vella, Andorra|OPERATIONAL    |Stella del Monaco            |5            |120                |our new friend maria alias augustina reception made our stay unforgettable mega friendly  mega patience  knows the resort more than her own pockets and is accompanied steadily with this amazing smile thank you very much s                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 |en             |our new friend maria alias augustina reception made our stay unforgettable mega friendly  mega patience  knows the resort more than her own pockets and is accompanied steadily with this amazing smile thank you very much s                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 |
# |dummy           |Grand Plaza Hotel & Wellness|4.5   |1301              |10              |Carrer de na Maria Pla, 19-21, AD500 Andorra la Vella, Andorra|OPERATIONAL    |Nathalie TAIEB               |5            |120                |an amazing experience  the spa is wonderful hotel and catering perfect as  well people  special mention for agustina we feel in our sweet home                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                |en             |an amazing experience  the spa is wonderful hotel and catering perfect as  well people  special mention for agustina we feel in our sweet home                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                |
# |dummy           |Hotel Mercure Andorra       |4     |1240              |10              |Carrer de la Roda, S N, AD500 Andorra la Vella, Andorra       |OPERATIONAL    |Ray                          |4            |120                |the hotel is old fashioned but full of features indoor swimming pool jacuzzi arcade room rooftop tennis it got all the staff are friendly i booked the room with breakfast but had to change plans to catch an earlier bus so didnt get to try the breakfast buffetits in the city center with restaurants and shopping all in walking distance                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               |en             |the hotel is old fashioned but full of features indoor swimming pool jacuzzi arcade room rooftop tennis it got all the staff are friendly i booked the room with breakfast but had to change plans to catch an earlier bus so didnt get to try the breakfast buffetits in the city center with restaurants and shopping all in walking distance                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               |
# |dummy           |Hotel Mercure Andorra       |4     |1240              |10              |Carrer de la Roda, S N, AD500 Andorra la Vella, Andorra       |OPERATIONAL    |Selia R                      |1            |120                |this is a review for the spa onlyi used to pay 20 euros a weekjust for the use of the sauna and sauna onlybecause  like others have stated previouslythe hygiene standards are very poor and even worrisomeconsidering dozens of people and kids jump into the pool not showeredand there are no shower gel or soap  in the locker rooms and the dance continues all day  while the hotel guests come in and out of the spawhen i told a man in his fortiesto remove his outside sandalsbefore entering the sauna he ran out to the reception   to complain and they actually said it was ok for him to wear his outside shoes in the sauna gross that same woman very moody to be in hospitalitynote to managementstormed in and embarrassed me in front of the other guests in the sauna screaming some non sense with her sneakers on while the rest of us are barefoot i left and they refused to refund me its oki am going back to the plaza its worth paying more for my health                                                                                                                                                                                        |en             |this is a review for the spa onlyi used to pay 20 euros a weekjust for the use of the sauna and sauna onlybecause  like others have stated previouslythe hygiene standards are very poor and even worrisomeconsidering dozens of people and kids jump into the pool not showeredand there are no shower gel or soap  in the locker rooms and the dance continues all day  while the hotel guests come in and out of the spawhen i told a man in his fortiesto remove his outside sandalsbefore entering the sauna he ran out to the reception   to complain and they actually said it was ok for him to wear his outside shoes in the sauna gross that same woman very moody to be in hospitalitynote to managementstormed in and embarrassed me in front of the other guests in the sauna screaming some non sense with her sneakers on while the rest of us are barefoot i left and they refused to refund me its oki am going back to the plaza its worth paying more for my health                                                                                                                                                                                        |
# |dummy           |Hotel Mercure Andorra       |4     |1240              |10              |Carrer de la Roda, S N, AD500 Andorra la Vella, Andorra       |OPERATIONAL    |Guru Raj                     |2            |270                |this place is a dump there is one electric outlet by the desk cant charge your phone by your bed the gym opens at 945 am there goes a chance to exercise before the day stars and the front desk staff dngaf about you im platinum with all thanks to stays at the fairmont mercure just doesnt care theres a dog barking in the room next door while i write thisthe hotel has clearly paid for positive reviews  while the photos are accurate the description of the experiences is both clearly written by ai and doesnt approximate realityon the positive side my kids asked what life was like in the 1970s till someone invents a time machine staying at this hotel is a very close approximation                                                                                                                                                                                                                                                                                                                                                                                                                                                                    |en             |this place is a dump there is one electric outlet by the desk cant charge your phone by your bed the gym opens at 945 am there goes a chance to exercise before the day stars and the front desk staff dngaf about you im platinum with all thanks to stays at the fairmont mercure just doesnt care theres a dog barking in the room next door while i write thisthe hotel has clearly paid for positive reviews  while the photos are accurate the description of the experiences is both clearly written by ai and doesnt approximate realityon the positive side my kids asked what life was like in the 1970s till someone invents a time machine staying at this hotel is a very close approximation                                                                                                                                                                                                                                                                                                                                                                                                                                                                    |
# |dummy           |Hotel Mercure Andorra       |4     |1240              |10              |Carrer de la Roda, S N, AD500 Andorra la Vella, Andorra       |OPERATIONAL    |L James                      |4            |300                |great hotel at a great price i did not give it 5 stars overall as my husband and i had the evening buffet meal but were a little disappointed to find the main meals were only luke warm there was a good selection of antipasto however and deserts the room was clean and comfortable and the location was superb as really central we will come back to this hotel if we stay in andorra again                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             |en             |great hotel at a great price i did not give it 5 stars overall as my husband and i had the evening buffet meal but were a little disappointed to find the main meals were only luke warm there was a good selection of antipasto however and deserts the room was clean and comfortable and the location was superb as really central we will come back to this hotel if we stay in andorra again                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             |
# |dummy           |Hotel Mercure Andorra       |4     |1240              |10              |Carrer de la Roda, S N, AD500 Andorra la Vella, Andorra       |OPERATIONAL    |Natalia Danilovich           |5            |300                |this hotel has nicely looking and renovated rooms and bathroom the location is great its in a short walking distance to the central part of the city with main sightseeing points lots of shops and restaurants despite the hotel is big it has a rather quiet atmosphere i liked our stay a lot                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              |en             |this hotel has nicely looking and renovated rooms and bathroom the location is great its in a short walking distance to the central part of the city with main sightseeing points lots of shops and restaurants despite the hotel is big it has a rather quiet atmosphere i liked our stay a lot                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              |
# |dummy           |Andorra Park Hotel          |4.6   |1024              |10              |Carrer les Canals, 24, AD500 Andorra la Vella, Andorra        |OPERATIONAL    |Nicolas                      |5            |0                  |i really enjoyed my stay there spacious rooms quiet great facilities beautiful scenery and just a lift away to the shopping street                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            |en             |i really enjoyed my stay there spacious rooms quiet great facilities beautiful scenery and just a lift away to the shopping street                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            |
# |dummy           |Andorra Park Hotel          |4.6   |1024              |10              |Carrer les Canals, 24, AD500 Andorra la Vella, Andorra        |OPERATIONAL    |Aleksandar Matic             |5            |0                  |ideal to disconnect relax and focus on your wellbeingwe are currently staying at andorra park  we couldnt imagine a better summer holiday amazing scenery quiet rooms comfortable beds  a great menu of pillows a nice spa and gym very professional and kind staff attention to detail   all super clean and comfy all the compliments for the managementa side note  tesla chargers easily availablefully recommended                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       |en             |ideal to disconnect relax and focus on your wellbeingwe are currently staying at andorra park  we couldnt imagine a better summer holiday amazing scenery quiet rooms comfortable beds  a great menu of pillows a nice spa and gym very professional and kind staff attention to detail   all super clean and comfy all the compliments for the managementa side note  tesla chargers easily availablefully recommended                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       |
# |dummy           |Andorra Park Hotel          |4.6   |1024              |10              |Carrer les Canals, 24, AD500 Andorra la Vella, Andorra        |OPERATIONAL    |Frederik Schleier            |5            |0                  |i stayed at the andorra park hotel for 3 nights overall i really enjoyed my stay rooms are very spacious balcony provides a nice view staff has been very friendly and helpful massage in the inhouse spa has been great gym with great modern equipment very fast access to the city center mattress in the room was sagging some details in the room really need maintenance lamp in the shower was hanging from the roof silicone on the tiles definitely need some renovation spa area especially sauna is tiny                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           |en             |i stayed at the andorra park hotel for 3 nights overall i really enjoyed my stay rooms are very spacious balcony provides a nice view staff has been very friendly and helpful massage in the inhouse spa has been great gym with great modern equipment very fast access to the city center mattress in the room was sagging some details in the room really need maintenance lamp in the shower was hanging from the roof silicone on the tiles definitely need some renovation spa area especially sauna is tiny                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           |
# |dummy           |Andorra Park Hotel          |4.6   |1024              |10              |Carrer les Canals, 24, AD500 Andorra la Vella, Andorra        |OPERATIONAL    |souad yassine                |5            |60                 |the room is  very big and comfortable and we have ours with great viewsthe hotel is located in the andorra la vella very clean  safe  quite place10 minutes walking from the hotel to the centre  the easiest way to go down is to use the left in the parking building and its also the for the pyrenees building where you can do ur shopping or if you want supermarket  the staff are very friendlywe stayed for 1 week and it wasnt enough to visit the whole andorrafor the people who like sky  hiking  or horse riding its the best place see you soon                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                |en             |the room is  very big and comfortable and we have ours with great viewsthe hotel is located in the andorra la vella very clean  safe  quite place10 minutes walking from the hotel to the centre  the easiest way to go down is to use the left in the parking building and its also the for the pyrenees building where you can do ur shopping or if you want supermarket  the staff are very friendlywe stayed for 1 week and it wasnt enough to visit the whole andorrafor the people who like sky  hiking  or horse riding its the best place see you soon                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                |
# |dummy           |Andorra Park Hotel          |4.6   |1024              |10              |Carrer les Canals, 24, AD500 Andorra la Vella, Andorra        |OPERATIONAL    |Xing Quan                    |1            |90                 |unfortunately we did not have a good experience the hotel itself is fine in the middle of the night after midnight one of the hanging lamps suddenly fell from the ceiling almost hurting one of our children as a result of the lamp falling the power for the unit shorted out and we had no lights or even keycard access into our room we called the front desk the receptionist came to our room to assess he was unfortunately drunk there was a very strong smell of alcohol from him and it was hard to understand him as well also his english wasnt good the best he could do was to offer us another room we had to move our entire family and all of our belongings at 1230 am we have two kids  at this point they were very tirednone of this to me is out of the ordinary what really disappointed us was that there was no apology from the front desk when we checked out the next morning when we brought up that we were extremely unhappy about the incident the front desk offered us free parking 15 euros a ridiculously small offer for our ordeal he also refused to put us through to speak with a manager we have already disputed the room charges|en             |unfortunately we did not have a good experience the hotel itself is fine in the middle of the night after midnight one of the hanging lamps suddenly fell from the ceiling almost hurting one of our children as a result of the lamp falling the power for the unit shorted out and we had no lights or even keycard access into our room we called the front desk the receptionist came to our room to assess he was unfortunately drunk there was a very strong smell of alcohol from him and it was hard to understand him as well also his english wasnt good the best he could do was to offer us another room we had to move our entire family and all of our belongings at 1230 am we have two kids  at this point they were very tirednone of this to me is out of the ordinary what really disappointed us was that there was no apology from the front desk when we checked out the next morning when we brought up that we were extremely unhappy about the incident the front desk offered us free parking 15 euros a ridiculously small offer for our ordeal he also refused to put us through to speak with a manager we have already disputed the room charges|
# |Andorra la Vella|Grand Plaza Hotel & Wellness|4.5   |1304              |10              |Carrer de na Maria Pla, 19-21, AD500 Andorra la Vella, Andorra|OPERATIONAL    |Rhian P                      |5.0          |90                 |this is a beautiful hotel with a wonderful doorman  best selection of fruit in the breakfast buffet i have ever seen  within walking distance of everything  we had one of the rooms on the top floor which had a lovely terrace looking up to the mountains  the only problem we had was that the room was very hot even when we turned the air conditioning cooler                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          |en             |this is a beautiful hotel with a wonderful doorman  best selection of fruit in the breakfast buffet i have ever seen  within walking distance of everything  we had one of the rooms on the top floor which had a lovely terrace looking up to the mountains  the only problem we had was that the room was very hot even when we turned the air conditioning cooler                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          |
# |Andorra la Vella|Grand Plaza Hotel & Wellness|4.5   |1304              |10              |Carrer de na Maria Pla, 19-21, AD500 Andorra la Vella, Andorra|OPERATIONAL    |Jan H                        |5.0          |21                 |augustina on front desk was really helpful and nice to all our requests i recommend the hotel lovely and comfortable beds so i slept so good probably best in year 2024 spa is ok and kids enjoy it restaurant in livy has great burgers and staff is really nice and helpful                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 |en             |augustina on front desk was really helpful and nice to all our requests i recommend the hotel lovely and comfortable beds so i slept so good probably best in year 2024 spa is ok and kids enjoy it restaurant in livy has great burgers and staff is really nice and helpful                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 |
# |Andorra la Vella|Grand Plaza Hotel & Wellness|4.5   |1304              |10              |Carrer de na Maria Pla, 19-21, AD500 Andorra la Vella, Andorra|OPERATIONAL    |Scarlet Cortés Santelices    |5.0          |90                 |im back in andorra and once again the hotel was amazing felipe and jose looked after us and they were super nice and attentive the whole time the spa needs an appointment but its seriously awesome and totally worth it plus the hotel is really close to all the shops which is awesome                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    |en             |im back in andorra and once again the hotel was amazing felipe and jose looked after us and they were super nice and attentive the whole time the spa needs an appointment but its seriously awesome and totally worth it plus the hotel is really close to all the shops which is awesome                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    |
# |Andorra la Vella|Grand Plaza Hotel & Wellness|4.5   |1304              |10              |Carrer de na Maria Pla, 19-21, AD500 Andorra la Vella, Andorra|OPERATIONAL    |Tatiana Siivinen             |4.0          |90                 |nice hotel in good location we stayed 5 days there they have 2 restaurants italian  very nice  and spanish  noodle was very salty and spicy and we asked if they are spicy before we order but burger and meat was ok  room was nice in the way but very very hot one night it was 275  all others 255 c we asked in the hotel and they told us that it is a temperature in the hotel so we cant change it we been opening window every once in the while but our girl was sleeping next to window so we couldnt keep it open for night nice breakfast with a lot of fruits spa is little but nice gym is little but ok  also very hot in there cause it is right next to spa department because of the uncomfortable nights in the hotel i wouldnt give it 5 stars                                                                                                                                                                                                                                                                                                                                                                                                           |en             |nice hotel in good location we stayed 5 days there they have 2 restaurants italian  very nice  and spanish  noodle was very salty and spicy and we asked if they are spicy before we order but burger and meat was ok  room was nice in the way but very very hot one night it was 275  all others 255 c we asked in the hotel and they told us that it is a temperature in the hotel so we cant change it we been opening window every once in the while but our girl was sleeping next to window so we couldnt keep it open for night nice breakfast with a lot of fruits spa is little but nice gym is little but ok  also very hot in there cause it is right next to spa department because of the uncomfortable nights in the hotel i wouldnt give it 5 stars                                                                                                                                                                                                                                                                                                                                                                                                           |
# |Andorra la Vella|Grand Plaza Hotel & Wellness|4.5   |1304              |10              |Carrer de na Maria Pla, 19-21, AD500 Andorra la Vella, Andorra|OPERATIONAL    |KLC331                       |5.0          |150                |we are on business in january 2024  our room was very clean modern and airy  excellent choice at breakfast as i eat a plant based diet  dinner in the italian restaurant was exceptional best pasta i have had outside italy  good central location to attend all our meetings  staff polite and very helpful  we have booked again in march and would highly recommend                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       |en             |we are on business in january 2024  our room was very clean modern and airy  excellent choice at breakfast as i eat a plant based diet  dinner in the italian restaurant was exceptional best pasta i have had outside italy  good central location to attend all our meetings  staff polite and very helpful  we have booked again in march and would highly recommend                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       |
# +----------------+----------------------------+------+------------------+----------------+--------------------------------------------------------------+---------------+-----------------------------+-------------+-------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+---------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# only showing top 20 rows
